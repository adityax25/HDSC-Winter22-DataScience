# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly
import plotly.express as px
import plotly.offline as pyo
import cufflinks as cf
pyo.init_notebook_mode(connected=True)
cf.go_offline()
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
# ...

# %%
url = "https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv"
fuel_data = pd.read_csv(url, error_bad_lines=False)
fuel_data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   record_id                     29523 non-null  object
#  1   utility_id_ferc1              29523 non-null  int64
#  2   report_year                   29523 non-null  int64
#  3   plant_name_ferc1              29523 non-null  object
#  4   fuel_type_code_pudl           29523 non-null  object
#  5   fuel_unit                     29343 non-null  object
#  6   fuel_qty_burned               29523 non-null  float64
#  7   fuel_mmbtu_per_unit           29523 non-null  float64
#  8   fuel_cost_per_unit_burned     29523 non-null  float64
#  9   fuel_cost_per_unit_delivered  29523 non-null  float64
#  10  fuel_cost_per_mmbtu           29523 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB

# %%
fuel_data.shape
# Out:
# (29523, 11)

# %%
fuel_data.describe(include='all')
# Out:
#                      record_id  utility_id_ferc1   report_year  \
# count                    29523      29523.000000  29523.000000
# unique                   29523               NaN           NaN
# top     f1_fuel_2014_12_88_0_2               NaN           NaN
# freq                         1               NaN           NaN
# mean                       NaN        118.601836   2005.806050
# std                        NaN         74.178353      7.025483
# min                        NaN          1.000000   1994.000000
# 25%                        NaN         55.000000   2000.000000
# 50%                        NaN        122.000000   2006.000000
# 75%                        NaN        176.000000   2012.000000
# max                        NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %%
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fuel_data.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
fuel_data[['fuel_unit']] = fuel_data[['fuel_unit']].fillna(value='mcf')

# %%
fuel_data.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
fuel_data.groupby('report_year')['report_year'].count()
# Out:
# report_year
# 1994    1235
# 1995    1201
# 1996    1088
# 1997    1094
# 1998    1107
# 1999    1050
# 2000    1373
# 2001    1356
# 2002    1205
# 2003    1211
# 2004    1192
# 2005    1269
# 2006    1243
# 2007    1264
# 2008    1228
# 2009    1222
# 2010    1261
# 2011    1240
# 2012    1243
# 2013    1199
# 2014    1171
# 2015    1093
# 2016    1034
# 2017     993
# 2018     951
# Name: report_year, dtype: int64

# %%
fuel_data.groupby('report_year').first()
# Out:
#                            record_id  utility_id_ferc1    plant_name_ferc1  \
# report_year
# 1994           f1_fuel_1994_12_1_0_7                 1            rockport
# 1995         f1_fuel_1995_12_200_0_1               200    aroostook valley
# 1996         f1_fuel_1996_12_204_0_1               204            seabrook
# 1997           f1_fuel_1997_12_1_0_7                 1  rockport total aeg
# 1998           f1_fuel_1998_12_1_0_7                 1  rockport total aeg
# 1999         f1_fuel_1999_12_141_0_1               141            boardman
# 2000         f1_fuel_2000_12_141_0_1               141            boardman
# 2001         f1_fuel_2001_12_195_0_1               195           pulliam 3
# 2002         f1_fuel_2002_12_195_0_1               195           pulliam 3
# 2003         f1_fuel_2003_12_283_0_1               283       talbot energy
# 2004           f1_fuel_2004_12_1_0_7                 1  rockport total aeg
# ...

# %%
fuels_df1 = fuel_data.iloc[:19000].reset_index(drop=True)
fuels_df2 = fuel_data.iloc[19000:].reset_index(drop=True)

# %%
assert len(fuel_data) == (len(fuels_df1) + len(fuels_df2))

# %%
inner = pd.merge(fuels_df1, fuels_df2, how="inner")
inner
# Out:
# Empty DataFrame
# Columns: [record_id, utility_id_ferc1, report_year, plant_name_ferc1, fuel_type_code_pudl, fuel_unit, fuel_qty_burned, fuel_mmbtu_per_unit, fuel_cost_per_unit_burned, fuel_cost_per_unit_delivered, fuel_cost_per_mmbtu]
# Index: []

# %%
outer = pd.merge(fuels_df1, fuels_df2, how="outer")
outer
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
left = pd.merge(fuels_df1, fuels_df2, how="left")
left
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# ...                         ...               ...          ...
# 18995   f1_fuel_2009_12_182_1_9               182         2009
# 18996  f1_fuel_2009_12_182_1_10               182         2009
# 18997  f1_fuel_2009_12_182_1_13               182         2009
# 18998  f1_fuel_2009_12_182_1_14               182         2009
# 18999    f1_fuel_2009_12_79_0_1                79         2009
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
right = pd.merge(fuels_df1, fuels_df2, how="right")
right
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0       f1_fuel_2009_12_79_0_2                79         2009
# 1       f1_fuel_2009_12_79_0_4                79         2009
# 2       f1_fuel_2009_12_79_0_5                79         2009
# 3       f1_fuel_2009_12_79_0_7                79         2009
# 4      f1_fuel_2009_12_79_0_10                79         2009
# ...                        ...               ...          ...
# 10518  f1_fuel_2018_12_12_0_13                12         2018
# 10519   f1_fuel_2018_12_12_1_1                12         2018
# 10520  f1_fuel_2018_12_12_1_10                12         2018
# 10521  f1_fuel_2018_12_12_1_13                12         2018
# 10522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  montrose                 oil       bbl          22912.0
# ...

# %%
data_to_concat = pd.DataFrame()

# %%
pd.concat([fuel_data, data_to_concat]).reset_index(drop=True)
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_data.duplicated().any()
# Out:
# False

# %%
plt.figure(figsize=(7, 4))
plt.xticks(rotation=90)

fuel_units = pd.DataFrame({
    'unit': ['A', 'B', 'C', 'D', 'E'],
    'count': [22, 566, 33, 45, 18]
})

sns.barplot(data=fuel_units, x='unit', y='count')
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5, 0, 'Fuel Unit')

# %%
g = sns.barplot(data=fuel_units, x='unit', y='count')
g.set_yscale('log')
g.set_ylim(1, 1000)
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5, 0, 'Fuel Unit')
